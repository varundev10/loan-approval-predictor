# %% [markdown]
# # Dataset Comparison and Selection
#
# ## Objective
# Compare the available datasets and choose the best one for the final loan approval capstone.

# %% [markdown]
# ## Datasets Considered
# 1. Loan Approval Synthetic Dataset
# 2. Loan Approval Kaggle Train Dataset
# 3. Titanic Variant Dataset

# %%
import pandas as pd

comparison = pd.DataFrame([
    {
        "Dataset": "Loan Approval Synthetic",
        "Rows": 4269,
        "Domain Match": "Strong",
        "Missing Values": "No",
        "Notes": "Clean and easy, but likely synthetic and suspiciously easy for tree models."
    },
    {
        "Dataset": "Loan Approval Kaggle",
        "Rows": 614,
        "Domain Match": "Strong",
        "Missing Values": "Yes",
        "Notes": "More realistic loan dataset with train and test split."
    },
    {
        "Dataset": "Titanic Variant",
        "Rows": 1309,
        "Domain Match": "Weak",
        "Missing Values": "Minimal",
        "Notes": "Off-topic for this capstone and has malformed headers."
    }
])

comparison

# %% [markdown]
# ## Selection Decision
# **Selected best dataset:** `../Dataset/LoanApprovalKaggle/train_u6lujuX_CVtuZ9i.csv`
#
# ### Why this dataset was selected
# - It matches the loan approval problem directly.
# - It includes a paired held-out test file.
# - It is more realistic than the synthetic dataset.
# - It is easier to justify in a report or viva because strong performance on it will look more credible.

# %% [markdown]
# ## Final Recommendation
# - Keep `loan_approval_synthetic_analysis.ipynb` as reference work.
# - Use the Kaggle loan dataset for the final capstone workflow.
# - Do not use the Titanic variant for the final project.
